# %% [markdown]
# # ToolBox test with FTDI
# https://www.analog.com/media/en/technical-documentation/data-sheets/ad9833.pdf

# %%
import os, sys

def gen_relative_path(target_path): 
    
    def del_same_parents(target_path, current_path):
        if len(target_path) * len(current_path) > 0:
            if target_path[0] == current_path[0]:
                target_path.pop(0)
                current_path.pop(0)
                del_same_parents(target_path, current_path)
            
    current_path = os.getcwd().replace('\\', '/').split('/')
    target_path = target_path.replace('\\', '/').split('/')
    del_same_parents(target_path, current_path)
    
    return ['..'] * len(current_path) + target_path


def append_source_relative_path(source_relative_path):
    sys.path.append(os.sep.join(source_relative_path))

# %%
# paths = ['']
# paths = [gen_relative_path(p) for p in paths]
# print(paths)

# %%
paths = [['..', '..', '..', '..', '..', '..', 'Signal Generators', 'bitbucket', 'github', 'codes'],
         ['..', '..', '..', '..', '..', '..', '..', '已完成', 'Bridges', 'bitbucket', 'github', 'codes'], 
         ['..', '..', '..', '..', '..', '..', 'FX2LP', 'bitbucket', 'github', 'codes'],
         ['..', '..', '..', '..', '..', '..', 'Utilities', 'bitbucket', 'github', 'codes'],
         ['..', '..', '..', 'codes']]

for path in paths:
    append_source_relative_path(path)

# %%
# paths = [['..', '..', '..', '..', '..', '..', 'ORM', 'bitbucket', 'github', 'codes'],
#          ['..', '..', '..', '..', '..', '..', 'USB', 'Universal Serial Bus', 'bitbucket', 'github', 'codes'],
#          ['..', '..', '..', '..', '..', '..', '..', '已完成', 'Bridges', 'bitbucket', 'github', 'codes'], 
#          ['..', '..', '..', '..', '..', '..', 'Utilities', 'bitbucket', 'github', 'codes'],
#          ['..', '..', '..', 'codes']]

# for path in paths:
#     append_source_relative_path(path)

# %%
# %pylab inline 

from signal_generators import tools
from clock_generators.si5351 import Si5351
from utilities.adapters import peripherals
import fx2lp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Debug mode?

# %%
cls = Si5351

cls.DEBUG_MODE_SHOW_BUS_DATA = False         # whether to show bus data. 
cls.DEBUG_MODE_PRINT_REGISTER = False        # whether to print registers.

# %% [markdown]
# ## Generators

# %%
with_hardware_device = False

if with_hardware_device:
    _i2c = peripherals.I2C.get_Ftdi_i2c() 
    
else:
    _i2c =  None  # using None for testing without actual hardware device.

bus = I2C(_i2c)
# Out:
# ****** Virtual device. Data may not be real ! ******

# %%
bus = fx2lp.I2C(as_400KHz = True)

# %%
si = cls(bus)

# %%
si.set_frequency(25.2e6)

# %%
# ad1.reset()
# ad2.reset()

# %%
# ad1.enable_output(False)
# ad2.enable_output(False)

# %%
tb = tools.ToolBox()

# %% [markdown]
# ## Frequency Sweeping

# %%
# freq_start = 10
# freq_end = 1e6

# %%
freq_start = 24.6e6
freq_end = 25.2e6

tb.sweep(si, freq_start = freq_start, freq_end = freq_end, n_freqs = 100,
         sweep_type = 'logarithm', direction = 'round_trip', n_cycles = 2,
         slot_duration = 0.01, between_cycle_seconds = 0)
# Out:
# Frequency: 24600000.00
# Frequency: 24605928.71
# Frequency: 24611858.85
# Frequency: 24617790.42
# Frequency: 24623723.42
# Frequency: 24629657.85
# Frequency: 24635593.71
# Frequency: 24641531.00
# Frequency: 24647469.72
# Frequency: 24653409.88
# Frequency: 24659351.46
# Frequency: 24665294.48
# Frequency: 24671238.92
# Frequency: 24677184.80
# Frequency: 24683132.12
# Frequency: 24689080.87
# Frequency: 24695031.05
# Frequency: 24700982.66
# Frequency: 24706935.71
# Frequency: 24712890.19
# Frequency: 24718846.11
# Frequency: 24724803.47
# Frequency: 24730762.26
# Frequency: 24736722.48
# Frequency: 24742684.15
# Frequency: 24748647.25
# Frequency: 24754611.78
# Frequency: 24760577.76
# Frequency: 24766545.17
# Frequency: 24772514.02
# Frequency: 24778484.31
# Frequency: 24784456.04
# Frequency: 24790429.20
# Frequency: 24796403.81
# Frequency: 24802379.86
# Frequency: 24808357.34
# Frequency: 24814336.27
# Frequency: 24820316.64
# Frequency: 24826298.45
# Frequency: 24832281.70
# Frequency: 24838266.39
# Frequency: 24844252.53
# Frequency: 24850240.10
# Frequency: 24856229.12
# Frequency: 24862219.59
# Frequency: 24868211.50
# Frequency: 24874204.85
# Frequency: 24880199.65
# Frequency: 24886195.89
# Frequency: 24892193.57
# Frequency: 24898192.71
# Frequency: 24904193.28
# Frequency: 24910195.31
# Frequency: 24916198.78
# Frequency: 24922203.70
# Frequency: 24928210.06
# Frequency: 24934217.87
# Frequency: 24940227.13
# Frequency: 24946237.84
# Frequency: 24952250.00
# Frequency: 24958263.60
# Frequency: 24964278.66
# Frequency: 24970295.16
# Frequency: 24976313.12
# Frequency: 24982332.52
# Frequency: 24988353.38
# Frequency: 24994375.69
# Frequency: 25000399.44
# Frequency: 25006424.65
# Frequency: 25012451.32
# Frequency: 25018479.43
# Frequency: 25024509.00
# Frequency: 25030540.02
# Frequency: 25036572.49
# Frequency: 25042606.42
# Frequency: 25048641.80
# Frequency: 25054678.64
# Frequency: 25060716.93
# Frequency: 25066756.68
# Frequency: 25072797.88
# Frequency: 25078840.54
# Frequency: 25084884.65
# Frequency: 25090930.23
# Frequency: 25096977.25
# Frequency: 25103025.74
# Frequency: 25109075.68
# Frequency: 25115127.08
# Frequency: 25121179.94
# Frequency: 25127234.26
# Frequency: 25133290.04
# Frequency: 25139347.28
# Frequency: 25145405.98
# Frequency: 25151466.13
# Frequency: 25157527.75
# Frequency: 25163590.83
# Frequency: 25169655.37
# Frequency: 25175721.37
# Frequency: 25181788.83
# Frequency: 25187857.76
# Frequency: 25193928.15
# Frequency: 25193928.15
# Frequency: 25187857.76
# Frequency: 25181788.83
# Frequency: 25175721.37
# Frequency: 25169655.37
# Frequency: 25163590.83
# Frequency: 25157527.75
# Frequency: 25151466.13
# Frequency: 25145405.98
# Frequency: 25139347.28
# Frequency: 25133290.04
# Frequency: 25127234.26
# Frequency: 25121179.94
# Frequency: 25115127.08
# Frequency: 25109075.68
# Frequency: 25103025.74
# Frequency: 25096977.25
# Frequency: 25090930.23
# Frequency: 25084884.65
# Frequency: 25078840.54
# Frequency: 25072797.88
# Frequency: 25066756.68
# Frequency: 25060716.93
# Frequency: 25054678.64
# Frequency: 25048641.80
# Frequency: 25042606.42
# Frequency: 25036572.49
# Frequency: 25030540.02
# Frequency: 25024509.00
# Frequency: 25018479.43
# Frequency: 25012451.32
# Frequency: 25006424.65
# Frequency: 25000399.44
# Frequency: 24994375.69
# Frequency: 24988353.38
# Frequency: 24982332.52
# Frequency: 24976313.12
# Frequency: 24970295.16
# Frequency: 24964278.66
# Frequency: 24958263.60
# Frequency: 24952250.00
# Frequency: 24946237.84
# Frequency: 24940227.13
# Frequency: 24934217.87
# Frequency: 24928210.06
# Frequency: 24922203.70
# Frequency: 24916198.78
# Frequency: 24910195.31
# Frequency: 24904193.28
# Frequency: 24898192.71
# Frequency: 24892193.57
# Frequency: 24886195.89
# Frequency: 24880199.65
# Frequency: 24874204.85
# Frequency: 24868211.50
# Frequency: 24862219.59
# Frequency: 24856229.12
# Frequency: 24850240.10
# Frequency: 24844252.53
# Frequency: 24838266.39
# Frequency: 24832281.70
# Frequency: 24826298.45
# Frequency: 24820316.64
# Frequency: 24814336.27
# Frequency: 24808357.34
# Frequency: 24802379.86
# Frequency: 24796403.81
# Frequency: 24790429.20
# Frequency: 24784456.04
# Frequency: 24778484.31
# Frequency: 24772514.02
# Frequency: 24766545.17
# Frequency: 24760577.76
# Frequency: 24754611.78
# Frequency: 24748647.25
# Frequency: 24742684.15
# Frequency: 24736722.48
# Frequency: 24730762.26
# Frequency: 24724803.47
# Frequency: 24718846.11
# Frequency: 24712890.19
# Frequency: 24706935.71
# Frequency: 24700982.66
# Frequency: 24695031.05
# Frequency: 24689080.87
# Frequency: 24683132.12
# Frequency: 24677184.80
# Frequency: 24671238.92
# Frequency: 24665294.48
# Frequency: 24659351.46
# Frequency: 24653409.88
# Frequency: 24647469.72
# Frequency: 24641531.00
# Frequency: 24635593.71
# Frequency: 24629657.85
# Frequency: 24623723.42
# Frequency: 24617790.42
# Frequency: 24611858.85
# Frequency: 24605928.71
# Frequency: 24600000.00
# Frequency: 24600000.00
# Frequency: 24605928.71
# Frequency: 24611858.85
# Frequency: 24617790.42
# Frequency: 24623723.42
# Frequency: 24629657.85
# Frequency: 24635593.71
# Frequency: 24641531.00
# Frequency: 24647469.72
# Frequency: 24653409.88
# Frequency: 24659351.46
# Frequency: 24665294.48
# Frequency: 24671238.92
# Frequency: 24677184.80
# Frequency: 24683132.12
# Frequency: 24689080.87
# Frequency: 24695031.05
# Frequency: 24700982.66
# Frequency: 24706935.71
# Frequency: 24712890.19
# Frequency: 24718846.11
# Frequency: 24724803.47
# Frequency: 24730762.26
# Frequency: 24736722.48
# Frequency: 24742684.15
# Frequency: 24748647.25
# Frequency: 24754611.78
# Frequency: 24760577.76
# Frequency: 24766545.17
# Frequency: 24772514.02
# Frequency: 24778484.31
# Frequency: 24784456.04
# Frequency: 24790429.20
# Frequency: 24796403.81
# Frequency: 24802379.86
# Frequency: 24808357.34
# Frequency: 24814336.27
# Frequency: 24820316.64
# Frequency: 24826298.45
# Frequency: 24832281.70
# Frequency: 24838266.39
# Frequency: 24844252.53
# Frequency: 24850240.10
# Frequency: 24856229.12
# Frequency: 24862219.59
# Frequency: 24868211.50
# Frequency: 24874204.85
# Frequency: 24880199.65
# Frequency: 24886195.89
# Frequency: 24892193.57
# Frequency: 24898192.71
# Frequency: 24904193.28
# Frequency: 24910195.31
# Frequency: 24916198.78
# Frequency: 24922203.70
# Frequency: 24928210.06
# Frequency: 24934217.87
# Frequency: 24940227.13
# Frequency: 24946237.84
# Frequency: 24952250.00
# Frequency: 24958263.60
# Frequency: 24964278.66
# Frequency: 24970295.16
# Frequency: 24976313.12
# Frequency: 24982332.52
# Frequency: 24988353.38
# Frequency: 24994375.69
# Frequency: 25000399.44
# Frequency: 25006424.65
# Frequency: 25012451.32
# Frequency: 25018479.43
# Frequency: 25024509.00
# Frequency: 25030540.02
# Frequency: 25036572.49
# Frequency: 25042606.42
# Frequency: 25048641.80
# Frequency: 25054678.64
# Frequency: 25060716.93
# Frequency: 25066756.68
# Frequency: 25072797.88
# Frequency: 25078840.54
# Frequency: 25084884.65
# Frequency: 25090930.23
# Frequency: 25096977.25
# Frequency: 25103025.74
# Frequency: 25109075.68
# Frequency: 25115127.08
# Frequency: 25121179.94
# Frequency: 25127234.26
# Frequency: 25133290.04
# Frequency: 25139347.28
# Frequency: 25145405.98
# Frequency: 25151466.13
# Frequency: 25157527.75
# Frequency: 25163590.83
# Frequency: 25169655.37
# Frequency: 25175721.37
# Frequency: 25181788.83
# Frequency: 25187857.76
# Frequency: 25193928.15
# Frequency: 25193928.15
# Frequency: 25187857.76
# Frequency: 25181788.83
# Frequency: 25175721.37
# Frequency: 25169655.37
# Frequency: 25163590.83
# Frequency: 25157527.75
# Frequency: 25151466.13
# Frequency: 25145405.98
# Frequency: 25139347.28
# Frequency: 25133290.04
# Frequency: 25127234.26
# Frequency: 25121179.94
# Frequency: 25115127.08
# Frequency: 25109075.68
# Frequency: 25103025.74
# Frequency: 25096977.25
# Frequency: 25090930.23
# Frequency: 25084884.65
# Frequency: 25078840.54
# Frequency: 25072797.88
# Frequency: 25066756.68
# Frequency: 25060716.93
# Frequency: 25054678.64
# Frequency: 25048641.80
# Frequency: 25042606.42
# Frequency: 25036572.49
# Frequency: 25030540.02
# Frequency: 25024509.00
# Frequency: 25018479.43
# Frequency: 25012451.32
# Frequency: 25006424.65
# Frequency: 25000399.44
# Frequency: 24994375.69
# Frequency: 24988353.38
# Frequency: 24982332.52
# Frequency: 24976313.12
# Frequency: 24970295.16
# Frequency: 24964278.66
# Frequency: 24958263.60
# Frequency: 24952250.00
# Frequency: 24946237.84
# Frequency: 24940227.13
# Frequency: 24934217.87
# Frequency: 24928210.06
# Frequency: 24922203.70
# Frequency: 24916198.78
# Frequency: 24910195.31
# Frequency: 24904193.28
# Frequency: 24898192.71
# Frequency: 24892193.57
# Frequency: 24886195.89
# Frequency: 24880199.65
# Frequency: 24874204.85
# Frequency: 24868211.50
# Frequency: 24862219.59
# Frequency: 24856229.12
# Frequency: 24850240.10
# Frequency: 24844252.53
# Frequency: 24838266.39
# Frequency: 24832281.70
# Frequency: 24826298.45
# Frequency: 24820316.64
# Frequency: 24814336.27
# Frequency: 24808357.34
# Frequency: 24802379.86
# Frequency: 24796403.81
# Frequency: 24790429.20
# Frequency: 24784456.04
# Frequency: 24778484.31
# Frequency: 24772514.02
# Frequency: 24766545.17
# Frequency: 24760577.76
# Frequency: 24754611.78
# Frequency: 24748647.25
# Frequency: 24742684.15
# Frequency: 24736722.48
# Frequency: 24730762.26
# Frequency: 24724803.47
# Frequency: 24718846.11
# Frequency: 24712890.19
# Frequency: 24706935.71
# Frequency: 24700982.66
# Frequency: 24695031.05
# Frequency: 24689080.87
# Frequency: 24683132.12
# Frequency: 24677184.80
# Frequency: 24671238.92
# Frequency: 24665294.48
# Frequency: 24659351.46
# Frequency: 24653409.88
# Frequency: 24647469.72
# Frequency: 24641531.00
# Frequency: 24635593.71
# Frequency: 24629657.85
# Frequency: 24623723.42
# Frequency: 24617790.42
# Frequency: 24611858.85
# Frequency: 24605928.71
# Frequency: 24600000.00
# [24600000.00000001,
#  24605928.71199698,
#  24611858.852840528,
#  24617790.42287502,
#  24623723.422444947,
#  24629657.851894733,
#  24635593.71156903,
#  24641531.001812536,
#  24647469.72297002,
#  24653409.87538634,
#  24659351.459406435,
#  24665294.475375332,
#  24671238.923638184,
#  24677184.80454008,
#  24683132.11842634,
#  24689080.865642328,
#  24695031.046533477,
#  24700982.661445312,
#  24706935.710723434,
#  24712890.194713585,
#  24718846.113761436,
#  24724803.468212895,
#  24730762.258413896,
#  24736722.484710466,
#  24742684.14744871,
#  24748647.246974815,
#  24754611.783635106,
#  24760577.757775832,
#  24766545.16974349,
#  24772514.0198846,
#  24778484.30854577,
#  24784456.03607369,
#  24790429.202815127,
#  24796403.809116945,
#  24802379.85532613,
#  24808357.341789614,
#  24814336.268854547,
#  24820316.636868123,
#  24826298.446177617,
#  24832281.697130386,
#  24838266.390073877,
#  24844252.525355663,
#  24850240.10332326,
#  24856229.1243244,
#  24862219.58870687,
#  24868211.496818528,
#  24874204.849007323,
#  24880199.64562128,
#  24886195.887008566,
#  24892193.573517274,
#  24898192.705495734,
#  24904193.283292316,
#  24910195.307255466,
#  24916198.777733713,
#  24922203.695075683,
#  24928210.059630066,
#  24934217.871745706,
#  24940227.131771367,
#  24946237.84005605,
#  24952249.996948797,
#  24958263.602798726,
#  24964278.657955043,
#  24970295.162767038,
#  24976313.117584135,
#  24982332.52275569,
#  24988353.378631297,
#  24994375.68556058,
#  25000399.443893254,
#  25006424.653979108,
#  25012451.31616802,
#  25018479.430810012,
#  25024508.99825503,
#  25030540.018853247,
#  25036572.492954887,
#  25042606.42091025,
#  25048641.803069722,
#  25054678.639783774,
#  25060716.931402955,
#  25066756.67827796,
#  25072797.880759403,
#  25078840.539198153,
#  25084884.653945096,
#  25090930.22535121,
#  25096977.253767557,
#  25103025.739545282,
#  25109075.683035668,
#  25115127.08458993,
#  25121179.944559515,
#  25127234.263295908,
#  25133290.04115068,
#  25139347.27847549,
#  25145405.97562207,
#  25151466.132942293,
#  25157527.750787973,
#  25163590.82951115,
#  25169655.369463902,
#  25175721.370998394,
#  25181788.834466875,
#  25187857.76022167,
#  25193928.148615204]

# %% [markdown]
# ## Function Toggling

# %%
duration_seconds, count, cycle_time = tb.toggle(si,
                                                fun = 'enable_output', params = ({'value': True}, {'value': False}),
                                                n_cycles = 10, slot_duration = 0.2, between_cycle_seconds = 0.2)
print('duration_seconds, count, cycle_time', duration_seconds, count, cycle_time)
# Out:
# duration_seconds, count, cycle_time 6.091586589813232 10 0.6091586589813233

# %% [markdown]
# ## Waveform Juggling

# %%
# tb.juggle((si, si),
#           freq_start = freq_start, freq_end = freq_end, n_freqs = 100, freqs_type = 'logarithm',
#           slot_duration = 0.2, between_cycle_seconds = 0.2,
#           n_juggles = 10)
