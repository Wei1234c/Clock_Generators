# %% [markdown]
# # Si5351 Functional test - with FTDI or FX2LP
# - https://www.silabs.com/documents/public/data-sheets/Si5351-B.pdf
# - https://www.silabs.com/documents/public/application-notes/AN619.pdf
# - https://www.silabs.com/content/usergenerated/asi/cloud/attachments/siliconlabs/en/community/groups/timing/knowledge-base/jcr:content/content/primary/blog/modifying_the_feedba-K8Pv/311668.pdf

# %%
import os, sys

def gen_relative_path(target_path): 
    
    def del_same_parents(target_path, current_path):
        if len(target_path) * len(current_path) > 0:
            if target_path[0] == current_path[0]:
                target_path.pop(0)
                current_path.pop(0)
                del_same_parents(target_path, current_path)
            
    current_path = os.getcwd().replace('\\', '/').split('/')
    target_path = target_path.replace('\\', '/').split('/')
    del_same_parents(target_path, current_path)
    
    return ['..'] * len(current_path) + target_path


def append_source_relative_path(source_relative_path):
    sys.path.append(os.sep.join(source_relative_path))

# %%
# paths = ['']
# paths = [gen_relative_path(p) for p in paths]
# print(paths)

# %%
paths = [['..', '..', '..', '..', '..', '..', '..', '已完成', 'Bridges', 'bitbucket', 'github', 'codes'],
         ['..', '..', '..', '..', '..', '..', 'FX2LP', 'bitbucket', 'github', 'codes'],
         ['..', '..', '..', '..', '..', '..', 'Utilities', 'bitbucket', 'github', 'codes'],
         ['..', '..', '..', 'codes']]

for path in paths:
    append_source_relative_path(path)

# %%
# %pylab inline

from clock_generators.si5351 import Si5351
from utilities.adapters import peripherals
import fx2lp
# Out:
# Populating the interactive namespace from numpy and matplotlib
# No USB device matches URL ftdi://ftdi:ft232h/1

# %%
import pandas as pd

#https://thispointer.com/python-pandas-how-to-display-full-dataframe-i-e-print-all-rows-columns-without-truncation/
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Debug mode?

# %%
cls = Si5351

cls.DEBUG_MODE_SHOW_BUS_DATA = False         # whether to show bus data. 
cls.DEBUG_MODE_PRINT_REGISTER = False        # whether to print registers.

# %% [markdown]
# ## Generators

# %%
with_hardware_device = False

if with_hardware_device:
    _i2c = peripherals.I2C.get_Ftdi_i2c() 
    
else:
    _i2c =  None  # using None for testing without actual hardware device.

    
bus = peripherals.I2C(_i2c)
# Out:
# ****** Virtual device. Data may not be real ! ******

# %%
bus = fx2lp.I2C(as_400KHz = True)

# %%
si = cls(bus)

# %% [markdown]
# ## Registers values file I/O

# %%
si.map.save_to_file('Initial_values.txt')
initial_values = si.map.read_file('Initial_values.txt')

# %%
# clock_builder_values = si.map.read_file('Si5351A-RevB-Registers.txt') 
clock_builder_values = si.map.read_file('Si5351A-RevB-Registers with CenterSS 6ns skew.txt')

# %%
# si.write_all_registers(initial_values)

# %%
si.map.reset()
si.read_all_registers()
# Out:
# [(0, 'Device_Status', 17),
#  (1, 'Interrupt_Status_Sticky', 240),
#  (2, 'Interrupt_Status_Mask', 0),
#  (3, 'Output_Enable_Control', 248),
#  (9, 'OEB_Pin_Enable_Control_Mask', 0),
#  (15, 'PLL_Input_Source', 0),
#  (16, 'CLK0_Control', 79),
#  (17, 'CLK1_Control', 79),
#  (18, 'CLK2_Control', 79),
#  (19, 'CLK3_Control', 207),
#  (20, 'CLK4_Control', 207),
#  (21, 'CLK5_Control', 207),
#  (22, 'CLK6_Control', 207),
#  (23, 'CLK7_Control', 207),
#  (24, 'CLK3_0_Disable_State', 0),
#  (25, 'CLK7_4_Disable_State', 0),
#  (26, 'Multisynth_NA_Parameters_26', 255),
#  (27, 'Multisynth_NA_Parameters_27', 255),
#  (28, 'Multisynth_NA_Parameters_28', 0),
#  (29, 'Multisynth_NA_Parameters_29', 16),
#  (30, 'Multisynth_NA_Parameters_30', 0),
#  (31, 'Multisynth_NA_Parameters_31', 240),
#  (32, 'Multisynth_NA_Parameters_32', 0),
#  (33, 'Multisynth_NA_Parameters_33', 0),
#  (34, 'Multisynth_NB_Parameters_34', 255),
#  (35, 'Multisynth_NB_Parameters_35', 255),
#  (36, 'Multisynth_NB_Parameters_36', 0),
#  (37, 'Multisynth_NB_Parameters_37', 16),
#  (38, 'Multisynth_NB_Parameters_38', 0),
#  (39, 'Multisynth_NB_Parameters_39', 240),
#  (40, 'Multisynth_NB_Parameters_40', 0),
#  (41, 'Multisynth_NB_Parameters_41', 0),
#  (42, 'Multisynth0_Parameters_42', 255),
#  (43, 'Multisynth0_Parameters_43', 255),
#  (44, 'Multisynth0_Parameters_44', 0),
#  (45, 'Multisynth0_Parameters_45', 16),
#  (46, 'Multisynth0_Parameters_46', 0),
#  (47, 'Multisynth0_Parameters_47', 240),
#  (48, 'Multisynth0_Parameters_48', 0),
#  (49, 'Multisynth0_Parameters_49', 0),
#  (50, 'Multisynth1_Parameters_50', 255),
#  (51, 'Multisynth1_Parameters_51', 255),
#  (52, 'Multisynth1_Parameters_52', 0),
#  (53, 'Multisynth1_Parameters_53', 16),
#  (54, 'Multisynth1_Parameters_54', 0),
#  (55, 'Multisynth1_Parameters_55', 240),
#  (56, 'Multisynth1_Parameters_56', 0),
#  (57, 'Multisynth1_Parameters_57', 0),
#  (58, 'Multisynth2_Parameters_58', 255),
#  (59, 'Multisynth2_Parameters_59', 255),
#  (60, 'Multisynth2_Parameters_60', 0),
#  (61, 'Multisynth2_Parameters_61', 16),
#  (62, 'Multisynth2_Parameters_62', 0),
#  (63, 'Multisynth2_Parameters_63', 240),
#  (64, 'Multisynth2_Parameters_64', 0),
#  (65, 'Multisynth2_Parameters_65', 0),
#  (66, 'Multisynth3_Parameters_66', 255),
#  (67, 'Multisynth3_Parameters_67', 255),
#  (68, 'Multisynth3_Parameters_68', 0),
#  (69, 'Multisynth3_Parameters_69', 16),
#  (70, 'Multisynth3_Parameters_70', 0),
#  (71, 'Multisynth3_Parameters_71', 240),
#  (72, 'Multisynth3_Parameters_72', 0),
#  (73, 'Multisynth3_Parameters_73', 0),
#  (74, 'Multisynth4_Parameters_74', 255),
#  (75, 'Multisynth4_Parameters_75', 255),
#  (76, 'Multisynth4_Parameters_76', 0),
#  (77, 'Multisynth4_Parameters_77', 16),
#  (78, 'Multisynth4_Parameters_78', 0),
#  (79, 'Multisynth4_Parameters_79', 240),
#  (80, 'Multisynth4_Parameters_80', 0),
#  (81, 'Multisynth4_Parameters_81', 0),
#  (82, 'Multisynth5_Parameters_82', 255),
#  (83, 'Multisynth5_Parameters_83', 255),
#  (84, 'Multisynth5_Parameters_84', 0),
#  (85, 'Multisynth5_Parameters_85', 16),
#  (86, 'Multisynth5_Parameters_86', 0),
#  (87, 'Multisynth5_Parameters_87', 240),
#  (88, 'Multisynth5_Parameters_88', 0),
#  (89, 'Multisynth5_Parameters_89', 0),
#  (90, 'Multisynth6_Parameters', 36),
#  (91, 'Multisynth7_Parameters', 36),
#  (92, 'Clock_6_and_7_Output_Divider', 0),
#  (149, 'Spread_Spectrum_Parameters_149', 0),
#  (150, 'Spread_Spectrum_Parameters_150', 191),
#  (151, 'Spread_Spectrum_Parameters_151', 127),
#  (152, 'Spread_Spectrum_Parameters_152', 255),
#  (153, 'Spread_Spectrum_Parameters_153', 0),
#  (154, 'Spread_Spectrum_Parameters_154', 0),
#  (155, 'Spread_Spectrum_Parameters_155', 198),
#  (156, 'Spread_Spectrum_Parameters_156', 0),
#  (157, 'Spread_Spectrum_Parameters_157', 0),
#  (158, 'Spread_Spectrum_Parameters_158', 127),
#  (159, 'Spread_Spectrum_Parameters_159', 255),
#  (160, 'Spread_Spectrum_Parameters_160', 0),
#  (161, 'Spread_Spectrum_Parameters_161', 0),
#  (162, 'VCXO_Parameter_162', 0),
#  (163, 'VCXO_Parameter_163', 0),
#  (164, 'VCXO_Parameter_164', 0),
#  (165, 'CLK0_Initial_Phase_Offset', 0),
#  (166, 'CLK1_Initial_Phase_Offset', 0),
#  (167, 'CLK2_Initial_Phase_Offset', 0),
#  (168, 'CLK3_Initial_Phase_Offset', 0),
#  (169, 'CLK4_Initial_Phase_Offset', 0),
#  (170, 'CLK5_Initial_Phase_Offset', 0),
#  (177, 'PLL_Reset', 0),
#  (183, 'Crystal_Internal_Load_Capacitance', 210),
#  (187, 'Fanout_Enable', 192)]

# %%
# si.map.save_to_file('Read_back_values.txt')
read_back_values = si.map.read_file('Read_back_values.txt')

# %% [markdown]
# ## Compare Register Value Sets

# %%
si.map.compare_values_sets(clock_builder_values, initial_values)
# Out:
# array([[  0.,  nan,   0.,   1.],
#        [  1.,  nan,   0.,   1.],
#        [  2.,  19.,   0.,   1.],
#        [  3.,   0., 248.,   1.],
#        [  4.,   0.,  nan,   1.],
#        [  7.,   1.,  nan,   1.],
#        [  9.,  nan,   0.,   1.],
#        [ 15.,   0.,   0.,   0.],
#        [ 16.,  15.,  79.,   1.],
#        [ 17.,  47.,  79.,   1.],
#        [ 18.,  47.,  79.,   1.],
#        [ 19., 140., 207.,   1.],
#        [ 20., 140., 207.,   1.],
#        [ 21., 140., 207.,   1.],
#        [ 22., 140., 207.,   1.],
#        [ 23., 140., 207.,   1.],
#        [ 24.,  nan,   0.,   1.],
#        [ 25.,  nan,   0.,   1.],
#        [ 26.,   0., 255.,   1.],
#        [ 27.,   1., 255.,   1.],
#        [ 28.,   0.,   0.,   0.],
#        [ 29.,  16.,  16.,   0.],
#        [ 30.,   0.,   0.,   0.],
#        [ 31.,   0., 240.,   1.],
#        [ 32.,   0.,   0.,   0.],
#        [ 33.,   0.,   0.,   0.],
#        [ 34.,   0., 255.,   1.],
#        [ 35.,   1., 255.,   1.],
#        [ 36.,   0.,   0.,   0.],
#        [ 37.,  16.,  16.,   0.],
#        [ 38.,   0.,   0.,   0.],
#        [ 39.,   0., 240.,   1.],
#        [ 40.,   0.,   0.,   0.],
#        [ 41.,   0.,   0.,   0.],
#        [ 42.,   0., 255.,   1.],
#        [ 43.,   1., 255.,   1.],
#        [ 44.,   0.,   0.,   0.],
#        [ 45.,  16.,  16.,   0.],
#        [ 46.,   0.,   0.,   0.],
#        [ 47.,   0., 240.,   1.],
#        [ 48.,   0.,   0.,   0.],
#        [ 49.,   0.,   0.,   0.],
#        [ 50.,   0., 255.,   1.],
#        [ 51.,   1., 255.,   1.],
#        [ 52.,   0.,   0.,   0.],
#        [ 53.,  16.,  16.,   0.],
#        [ 54.,   0.,   0.,   0.],
#        [ 55.,   0., 240.,   1.],
#        [ 56.,   0.,   0.,   0.],
#        [ 57.,   0.,   0.,   0.],
#        [ 58.,   0., 255.,   1.],
#        [ 59.,   1., 255.,   1.],
#        [ 60.,   0.,   0.,   0.],
#        [ 61.,  16.,  16.,   0.],
#        [ 62.,   0.,   0.,   0.],
#        [ 63.,   0., 240.,   1.],
#        [ 64.,   0.,   0.,   0.],
#        [ 65.,   0.,   0.,   0.],
#        [ 66.,  nan, 255.,   1.],
#        [ 67.,  nan, 255.,   1.],
#        [ 68.,  nan,   0.,   1.],
#        [ 69.,  nan,  16.,   1.],
#        [ 70.,  nan,   0.,   1.],
#        [ 71.,  nan, 240.,   1.],
#        [ 72.,  nan,   0.,   1.],
#        [ 73.,  nan,   0.,   1.],
#        [ 74.,  nan, 255.,   1.],
#        [ 75.,  nan, 255.,   1.],
#        [ 76.,  nan,   0.,   1.],
#        [ 77.,  nan,  16.,   1.],
#        [ 78.,  nan,   0.,   1.],
#        [ 79.,  nan, 240.,   1.],
#        [ 80.,  nan,   0.,   1.],
#        [ 81.,  nan,   0.,   1.],
#        [ 82.,  nan, 255.,   1.],
#        [ 83.,  nan, 255.,   1.],
#        [ 84.,  nan,   0.,   1.],
#        [ 85.,  nan,  16.,   1.],
#        [ 86.,  nan,   0.,   1.],
#        [ 87.,  nan, 240.,   1.],
#        [ 88.,  nan,   0.,   1.],
#        [ 89.,  nan,   0.,   1.],
#        [ 90.,   0.,  36.,   1.],
#        [ 91.,   0.,  36.,   1.],
#        [ 92.,  nan,   0.,   1.],
#        [149., 130.,   0.,   1.],
#        [150., 249.,   0.,   1.],
#        [151., 255.,   0.,   1.],
#        [152., 255.,   0.,   1.],
#        [153.,   0.,   0.,   0.],
#        [154.,   0.,   0.,   0.],
#        [155., 198.,   0.,   1.],
#        [156.,   2.,   0.,   1.],
#        [157., 251.,   0.,   1.],
#        [158., 127.,   0.,   1.],
#        [159., 255.,   0.,   1.],
#        [160.,   0.,   0.,   0.],
#        [161.,   0.,   0.,   0.],
#        [162.,   0.,   0.,   0.],
#        [163.,   0.,   0.,   0.],
#        [164.,   0.,   0.,   0.],
#        [165.,  22.,   0.,   1.],
#        [166.,   0.,   0.,   0.],
#        [167.,   0.,   0.,   0.],
#        [168.,  nan,   0.,   1.],
#        [169.,  nan,   0.,   1.],
#        [170.,  nan,   0.,   1.],
#        [177.,  nan,   0.,   1.],
#        [183., 210., 210.,   0.],
#        [187.,  nan, 192.,   1.]])

# %%
df = si.map.compare_values_sets_pd(clock_builder_values, initial_values)
df[df.different == 1]
# Out:
# There is no register as address 4.
# There is no register as address 7.
#                            register  address  default_value     element_name  \
# 3                     Device_Status        0              0        LOS_CLKIN
# 6                     Device_Status        0              0            REVID
# 7           Interrupt_Status_Sticky        1              0    SYS_INIT_STKY
# 8           Interrupt_Status_Sticky        1              0       LOL_B_STKY
# 9           Interrupt_Status_Sticky        1              0       LOL_A_STKY
# 10          Interrupt_Status_Sticky        1              0   LOS_CLKIN_STKY
# 16            Interrupt_Status_Mask        2              0  LOS__CLKIN_MASK
# 19            Output_Enable_Control        3              0         CLK7_OEB
# 20            Output_Enable_Control        3              0         CLK6_OEB
# 21            Output_Enable_Control        3              0         CLK5_OEB
# 22            Output_Enable_Control        3              0         CLK4_OEB
# 23            Output_Enable_Control        3              0         CLK3_OEB
# 41                     CLK0_Control       16              0          MS0_INT
# 47                     CLK1_Control       17              0          MS1_INT
# 48                     CLK1_Control       17              0          MS1_SRC
# 53                     CLK2_Control       18              0          MS2_INT
# 54                     CLK2_Control       18              0          MS2_SRC
# 59                     CLK3_Control       19              0          MS3_INT
# 63                     CLK3_Control       19              0        CLK3_IDRV
# 65                     CLK4_Control       20              0          MS4_INT
# 69                     CLK4_Control       20              0        CLK4_IDRV
# 71                     CLK5_Control       21              0          MS5_INT
# 75                     CLK5_Control       21              0        CLK5_IDRV
# 77                     CLK6_Control       22              0          FBA_INT
# 81                     CLK6_Control       22              0        CLK6_IDRV
# 83                     CLK7_Control       23              0          FBB_INT
# 87                     CLK7_Control       23              0        CLK7_IDRV
# 96      Multisynth_NA_Parameters_26       26              0     MSNA_P3_15_8
# 97      Multisynth_NA_Parameters_27       27              0      MSNA_P3_7_0
# 103     Multisynth_NA_Parameters_31       31              0    MSNA_P3_19_16
# 107     Multisynth_NB_Parameters_34       34              0     MSNB_P3_15_8
# 108     Multisynth_NB_Parameters_35       35              0      MSNB_P3_7_0
# 114     Multisynth_NB_Parameters_39       39              0    MSNB_P3_19_16
# 118       Multisynth0_Parameters_42       42              0      MS0_P3_15_8
# 119       Multisynth0_Parameters_43       43              0       MS0_P3_7_0
# 126       Multisynth0_Parameters_47       47              0     MS0_P3_19_16
# 130       Multisynth1_Parameters_50       50              0      MS1_P3_15_8
# 131       Multisynth1_Parameters_51       51              0       MS1_P3_7_0
# 138       Multisynth1_Parameters_55       55              0     MS1_P3_19_16
# 142       Multisynth2_Parameters_58       58              0      MS2_P3_15_8
# 143       Multisynth2_Parameters_59       59              0       MS2_P3_7_0
# 150       Multisynth2_Parameters_63       63              0     MS2_P3_19_16
# 190          Multisynth6_Parameters       90              0       MS6_P1_7_0
# 191          Multisynth7_Parameters       91              0       MS7_P1_7_0
# 196  Spread_Spectrum_Parameters_149      149              0           SSC_EN
# 197  Spread_Spectrum_Parameters_149      149              0     SSDN_P2_14_8
# 198  Spread_Spectrum_Parameters_150      150              0      SSDN_P2_7_0
# 199  Spread_Spectrum_Parameters_151      151              0         SSC_MODE
# 200  Spread_Spectrum_Parameters_151      151              0     SSDN_P3_14_8
# 201  Spread_Spectrum_Parameters_152      152              0      SSDN_P3_7_0
# 205  Spread_Spectrum_Parameters_155      155              0        SSUDP_7_0
# 207  Spread_Spectrum_Parameters_156      156              0     SSUP_P2_14_8
# 208  Spread_Spectrum_Parameters_157      157              0      SSUP_P2_7_0
# 210  Spread_Spectrum_Parameters_158      158              0     SSUP_P3_14_8
# 211  Spread_Spectrum_Parameters_159      159              0      SSUP_P3_7_0
# 220       CLK0_Initial_Phase_Offset      165              0       CLK0_PHOFF
#
#      idx_lowest_bit  n_bits  read_only  value  value_2  different
# 3                 4       1      False      1        0          1
# 6                 0       2      False      1        0          1
# 7                 7       1      False      1        0          1
# 8                 6       1      False      1        0          1
# 9                 5       1      False      1        0          1
# 10                4       1      False      1        0          1
# 16                4       1      False      1        0          1
# 19                7       1      False      0        1          1
# 20                6       1      False      0        1          1
# 21                5       1      False      0        1          1
# 22                4       1      False      0        1          1
# 23                3       1      False      0        1          1
# 41                6       1      False      0        1          1
# 47                6       1      False      0        1          1
# 48                5       1      False      1        0          1
# 53                6       1      False      0        1          1
# 54                5       1      False      1        0          1
# 59                6       1      False      0        1          1
# 63                0       2      False      0        3          1
# 65                6       1      False      0        1          1
# 69                0       2      False      0        3          1
# 71                6       1      False      0        1          1
# 75                0       2      False      0        3          1
# 77                6       1      False      0        1          1
# 81                0       2      False      0        3          1
# 83                6       1      False      0        1          1
# 87                0       2      False      0        3          1
# 96                0       8      False      0      255          1
# 97                0       8      False      1      255          1
# 103               4       4      False      0       15          1
# 107               0       8      False      0      255          1
# 108               0       8      False      1      255          1
# 114               4       4      False      0       15          1
# 118               0       8      False      0      255          1
# 119               0       8      False      1      255          1
# 126               4       4      False      0       15          1
# 130               0       8      False      0      255          1
# 131               0       8      False      1      255          1
# 138               4       4      False      0       15          1
# 142               0       8      False      0      255          1
# 143               0       8      False      1      255          1
# 150               4       4      False      0       15          1
# 190               0       8      False      0       36          1
# 191               0       8      False      0       36          1
# 196               7       1      False      1        0          1
# 197               0       7      False      2        0          1
# 198               0       8      False    249        0          1
# 199               7       1      False      1        0          1
# 200               0       7      False    127        0          1
# 201               0       8      False    255        0          1
# 205               0       8      False    198        0          1
# 207               0       7      False      2        0          1
# 208               0       8      False    251        0          1
# 210               0       7      False    127        0          1
# 211               0       8      False    255        0          1
# 220               0       7      False     22        0          1

# %%
si.map.compare_values_sets(initial_values, read_back_values)
# Out:
# array([[  0.,   0.,  17.,   1.],
#        [  1.,   0., 240.,   1.],
#        [  2.,   0.,   0.,   0.],
#        [  3., 248., 248.,   0.],
#        [  9.,   0.,   0.,   0.],
#        [ 15.,   0.,   0.,   0.],
#        [ 16.,  79.,  79.,   0.],
#        [ 17.,  79.,  79.,   0.],
#        [ 18.,  79.,  79.,   0.],
#        [ 19., 207., 207.,   0.],
#        [ 20., 207., 207.,   0.],
#        [ 21., 207., 207.,   0.],
#        [ 22., 207., 207.,   0.],
#        [ 23., 207., 207.,   0.],
#        [ 24.,   0.,   0.,   0.],
#        [ 25.,   0.,   0.,   0.],
#        [ 26., 255., 255.,   0.],
#        [ 27., 255., 255.,   0.],
#        [ 28.,   0.,   0.,   0.],
#        [ 29.,  16.,  16.,   0.],
#        [ 30.,   0.,   0.,   0.],
#        [ 31., 240., 240.,   0.],
#        [ 32.,   0.,   0.,   0.],
#        [ 33.,   0.,   0.,   0.],
#        [ 34., 255., 255.,   0.],
#        [ 35., 255., 255.,   0.],
#        [ 36.,   0.,   0.,   0.],
#        [ 37.,  16.,  16.,   0.],
#        [ 38.,   0.,   0.,   0.],
#        [ 39., 240., 240.,   0.],
#        [ 40.,   0.,   0.,   0.],
#        [ 41.,   0.,   0.,   0.],
#        [ 42., 255., 255.,   0.],
#        [ 43., 255., 255.,   0.],
#        [ 44.,   0.,   0.,   0.],
#        [ 45.,  16.,  16.,   0.],
#        [ 46.,   0.,   0.,   0.],
#        [ 47., 240., 240.,   0.],
#        [ 48.,   0.,   0.,   0.],
#        [ 49.,   0.,   0.,   0.],
#        [ 50., 255., 255.,   0.],
#        [ 51., 255., 255.,   0.],
#        [ 52.,   0.,   0.,   0.],
#        [ 53.,  16.,  16.,   0.],
#        [ 54.,   0.,   0.,   0.],
#        [ 55., 240., 240.,   0.],
#        [ 56.,   0.,   0.,   0.],
#        [ 57.,   0.,   0.,   0.],
#        [ 58., 255., 255.,   0.],
#        [ 59., 255., 255.,   0.],
#        [ 60.,   0.,   0.,   0.],
#        [ 61.,  16.,  16.,   0.],
#        [ 62.,   0.,   0.,   0.],
#        [ 63., 240., 240.,   0.],
#        [ 64.,   0.,   0.,   0.],
#        [ 65.,   0.,   0.,   0.],
#        [ 66., 255., 255.,   0.],
#        [ 67., 255., 255.,   0.],
#        [ 68.,   0.,   0.,   0.],
#        [ 69.,  16.,  16.,   0.],
#        [ 70.,   0.,   0.,   0.],
#        [ 71., 240., 240.,   0.],
#        [ 72.,   0.,   0.,   0.],
#        [ 73.,   0.,   0.,   0.],
#        [ 74., 255., 255.,   0.],
#        [ 75., 255., 255.,   0.],
#        [ 76.,   0.,   0.,   0.],
#        [ 77.,  16.,  16.,   0.],
#        [ 78.,   0.,   0.,   0.],
#        [ 79., 240., 240.,   0.],
#        [ 80.,   0.,   0.,   0.],
#        [ 81.,   0.,   0.,   0.],
#        [ 82., 255., 255.,   0.],
#        [ 83., 255., 255.,   0.],
#        [ 84.,   0.,   0.,   0.],
#        [ 85.,  16.,  16.,   0.],
#        [ 86.,   0.,   0.,   0.],
#        [ 87., 240., 240.,   0.],
#        [ 88.,   0.,   0.,   0.],
#        [ 89.,   0.,   0.,   0.],
#        [ 90.,  36.,  36.,   0.],
#        [ 91.,  36.,  36.,   0.],
#        [ 92.,   0.,   0.,   0.],
#        [149.,   0.,   0.,   0.],
#        [150.,   0.,   0.,   0.],
#        [151.,   0.,   0.,   0.],
#        [152.,   0.,   0.,   0.],
#        [153.,   0.,   0.,   0.],
#        [154.,   0.,   0.,   0.],
#        [155.,   0.,   0.,   0.],
#        [156.,   0.,   0.,   0.],
#        [157.,   0.,   0.,   0.],
#        [158.,   0.,   0.,   0.],
#        [159.,   0.,   0.,   0.],
#        [160.,   0.,   0.,   0.],
#        [161.,   0.,   0.,   0.],
#        [162.,   0.,   0.,   0.],
#        [163.,   0.,   0.,   0.],
#        [164.,   0.,   0.,   0.],
#        [165.,   0.,   0.,   0.],
#        [166.,   0.,   0.,   0.],
#        [167.,   0.,   0.,   0.],
#        [168.,   0.,   0.,   0.],
#        [169.,   0.,   0.,   0.],
#        [170.,   0.,   0.,   0.],
#        [177.,   0.,   0.,   0.],
#        [183., 210., 210.,   0.],
#        [187., 192., 192.,   0.]])

# %%
df = si.map.compare_values_sets_pd(initial_values, read_back_values)
df[df.different == 1]
# Out:
#                    register  address  default_value    element_name  \
# 3             Device_Status        0              0       LOS_CLKIN
# 6             Device_Status        0              0           REVID
# 7   Interrupt_Status_Sticky        1              0   SYS_INIT_STKY
# 8   Interrupt_Status_Sticky        1              0      LOL_B_STKY
# 9   Interrupt_Status_Sticky        1              0      LOL_A_STKY
# 10  Interrupt_Status_Sticky        1              0  LOS_CLKIN_STKY
#
#     idx_lowest_bit  n_bits  read_only  value  value_2  different
# 3                4       1      False      0        1          1
# 6                0       2      False      0        1          1
# 7                7       1      False      0        1          1
# 8                6       1      False      0        1          1
# 9                5       1      False      0        1          1
# 10               4       1      False      0        1          1

# %% [markdown]
# ## Find Integer Dividers for a Frequency

# %%
matchs = si.find_integer_dividers(freq_desired = 90e6, even_only = True, torance_hz = 1) 
matchs
# Out:
# [((36, 10, 1), (25000000, 900000000, 90000000, 90000000))]

# %%
matchs = si.find_integer_dividers(freq_desired = 150e6, even_only = True, torance_hz = 1) 
matchs
# Out:
# [((36, 6, 1), (25000000, 900000000, 150000000, 150000000))]

# %% [markdown]
# ## Find Common Integer Dividers for Frequencies

# %%
desired_clock_freqs = (45e6, 30e5, 90e6)
# desired_clock_freqs = (125e6, 48e6, 28.322e6, 74.25e6, 74.25e6, 24.576e6, 22.5792e6, 33.3333e6)
# desired_clock_freqs = (125e6, 48e6, 28.322e6, 74.25e6, 74.25e6, 24.576e6, 22.5792e6, 33.3333e6)
# desired_clock_freqs = (25e6, 25e6)

common_pll_dividers, freqs_pll_dividers, freqs_matches = si.find_integer_pll_dividers_for_clocks(desired_clock_freqs)
common_pll_dividers, freqs_pll_dividers
# Out:
# ({36}, [{36}, {24, 30, 36}, {36}])

# %% [markdown]
# ## Current Configuration

# %%
si.init()

# %%
si.clocks[0].set_phase(90)

# %%
si.current_configuration
# Out:
#   mclk_type  mclk_idx  mclk_freq  pll_idx  pll_divider   pll_freq  \
# 0     _Xtal         0   25000000        0           36  900000000
# 1     _Xtal         0   25000000        0           36  900000000
# 2     _Xtal         0   25000000        0           36  900000000
# 3     _Xtal         0   25000000        0           36  900000000
# 4     _Xtal         0   25000000        0           36  900000000
# 5     _Xtal         0   25000000        0           36  900000000
# 6     _Xtal         0   25000000        0           36  900000000
# 7     _Xtal         0   25000000        0           36  900000000
# 8     _Xtal         0   25000000        1           36  900000000
#
#    multisynth_idx  multisynth_divider  multisynth_freq  \
# 0             0.0                36.0       25000000.0
# 1             1.0                36.0       25000000.0
# 2             2.0                36.0       25000000.0
# 3             3.0                36.0       25000000.0
# 4             4.0                36.0       25000000.0
# 5             5.0                36.0       25000000.0
# 6             6.0                36.0       25000000.0
# 7             7.0                36.0       25000000.0
# 8             NaN                 NaN              NaN
#
#   multisynth_in_integer_mode multisynth_divided_by_4  clock_idx  \
# 0                      False                   False        0.0
# 1                       True                   False        1.0
# 2                       True                   False        2.0
# 3                       True                   False        3.0
# 4                       True                   False        4.0
# 5                       True                   False        5.0
# 6                       True                   False        6.0
# 7                       True                   False        7.0
# 8                        NaN                     NaN        NaN
#
#    clock_divider  clock_freq power_downed enabled oeb_pin_masked  \
# 0            1.0  25000000.0        False    True          False
# 1            1.0  25000000.0        False    True          False
# 2            1.0  25000000.0        False    True          False
# 3            1.0  25000000.0         True   False          False
# 4            1.0  25000000.0         True   False          False
# 5            1.0  25000000.0         True   False          False
# 6            1.0  25000000.0         True   False          False
# 7            1.0  25000000.0         True   False          False
# 8            NaN         NaN          NaN     NaN            NaN
#
#   phase_offset_enabled  phase
# 0                 True   90.0
# 1                False    0.0
# 2                False    0.0
# 3                False    0.0
# 4                False    0.0
# 5                False    0.0
# 6                False    0.0
# 7                False    0.0
# 8                  NaN    NaN

# %% [markdown]
# ## Main functions test

# %%
for f in dir(cls):
    if not f.startswith('_'):
        print('si.{}()'.format(f))
# Out:
# si.DEBUG_MODE()
# si.DEBUG_MODE_PRINT_REGISTER()
# si.DEBUG_MODE_SHOW_BUS_DATA()
# si.FREQ_REF()
# si.HAS_VCXO()
# si.I2C_ADDRESS()
# si.N_OUTPUT_CLOCKS()
# si.OUTPUT_CLOCKS_IN_USE()
# si.READ_ONLY_REGISTERS()
# si.close()
# si.current_configuration()
# si.current_frequency()
# si.current_phase()
# si.do()
# si.do_on_devices()
# si.enable()
# si.enable_output()
# si.enable_output_channel()
# si.find_integer_dividers()
# si.find_integer_pll_dividers_for_clocks()
# si.init()
# si.is_virtual_device()
# si.load_registers()
# si.pause()
# si.print()
# si.read_all_registers()
# si.ready()
# si.registers_values()
# si.reset()
# si.reset_plls()
# si.restore_clocks_freqs()
# si.resume()
# si.revision()
# si.set_frequency()
# si.set_phase()
# si.start()
# si.status()
# si.stop()
# si.update()
# si.write_all_registers()

# %%
si.init()

# %%
si.is_virtual_device
# Out:
# False

# %%
si.revision
# Out:
# 1

# %%
# si.set_frequency(2323)

# %%
# si.set_phase(55)

# %%
si.reset()

# %%
# si.current_frequency

# %%
# si.current_phase

# %%
si.enable()

# %%
si.enable_output()

# %%
si.enable_output_channel(0)

# %%
si.load_registers(initial_values)

# %%
si.read_all_registers()
# Out:
# [(0, 'Device_Status', 17),
#  (1, 'Interrupt_Status_Sticky', 240),
#  (2, 'Interrupt_Status_Mask', 0),
#  (3, 'Output_Enable_Control', 0),
#  (9, 'OEB_Pin_Enable_Control_Mask', 0),
#  (15, 'PLL_Input_Source', 0),
#  (16, 'CLK0_Control', 0),
#  (17, 'CLK1_Control', 0),
#  (18, 'CLK2_Control', 0),
#  (19, 'CLK3_Control', 0),
#  (20, 'CLK4_Control', 0),
#  (21, 'CLK5_Control', 0),
#  (22, 'CLK6_Control', 0),
#  (23, 'CLK7_Control', 0),
#  (24, 'CLK3_0_Disable_State', 0),
#  (25, 'CLK7_4_Disable_State', 0),
#  (26, 'Multisynth_NA_Parameters_26', 0),
#  (27, 'Multisynth_NA_Parameters_27', 0),
#  (28, 'Multisynth_NA_Parameters_28', 0),
#  (29, 'Multisynth_NA_Parameters_29', 0),
#  (30, 'Multisynth_NA_Parameters_30', 0),
#  (31, 'Multisynth_NA_Parameters_31', 0),
#  (32, 'Multisynth_NA_Parameters_32', 0),
#  (33, 'Multisynth_NA_Parameters_33', 0),
#  (34, 'Multisynth_NB_Parameters_34', 0),
#  (35, 'Multisynth_NB_Parameters_35', 0),
#  (36, 'Multisynth_NB_Parameters_36', 0),
#  (37, 'Multisynth_NB_Parameters_37', 0),
#  (38, 'Multisynth_NB_Parameters_38', 0),
#  (39, 'Multisynth_NB_Parameters_39', 0),
#  (40, 'Multisynth_NB_Parameters_40', 0),
#  (41, 'Multisynth_NB_Parameters_41', 0),
#  (42, 'Multisynth0_Parameters_42', 0),
#  (43, 'Multisynth0_Parameters_43', 0),
#  (44, 'Multisynth0_Parameters_44', 0),
#  (45, 'Multisynth0_Parameters_45', 0),
#  (46, 'Multisynth0_Parameters_46', 0),
#  (47, 'Multisynth0_Parameters_47', 0),
#  (48, 'Multisynth0_Parameters_48', 0),
#  (49, 'Multisynth0_Parameters_49', 0),
#  (50, 'Multisynth1_Parameters_50', 0),
#  (51, 'Multisynth1_Parameters_51', 0),
#  (52, 'Multisynth1_Parameters_52', 0),
#  (53, 'Multisynth1_Parameters_53', 0),
#  (54, 'Multisynth1_Parameters_54', 0),
#  (55, 'Multisynth1_Parameters_55', 0),
#  (56, 'Multisynth1_Parameters_56', 0),
#  (57, 'Multisynth1_Parameters_57', 0),
#  (58, 'Multisynth2_Parameters_58', 0),
#  (59, 'Multisynth2_Parameters_59', 0),
#  (60, 'Multisynth2_Parameters_60', 0),
#  (61, 'Multisynth2_Parameters_61', 0),
#  (62, 'Multisynth2_Parameters_62', 0),
#  (63, 'Multisynth2_Parameters_63', 0),
#  (64, 'Multisynth2_Parameters_64', 0),
#  (65, 'Multisynth2_Parameters_65', 0),
#  (66, 'Multisynth3_Parameters_66', 0),
#  (67, 'Multisynth3_Parameters_67', 0),
#  (68, 'Multisynth3_Parameters_68', 0),
#  (69, 'Multisynth3_Parameters_69', 0),
#  (70, 'Multisynth3_Parameters_70', 0),
#  (71, 'Multisynth3_Parameters_71', 0),
#  (72, 'Multisynth3_Parameters_72', 0),
#  (73, 'Multisynth3_Parameters_73', 0),
#  (74, 'Multisynth4_Parameters_74', 0),
#  (75, 'Multisynth4_Parameters_75', 0),
#  (76, 'Multisynth4_Parameters_76', 0),
#  (77, 'Multisynth4_Parameters_77', 0),
#  (78, 'Multisynth4_Parameters_78', 0),
#  (79, 'Multisynth4_Parameters_79', 0),
#  (80, 'Multisynth4_Parameters_80', 0),
#  (81, 'Multisynth4_Parameters_81', 0),
#  (82, 'Multisynth5_Parameters_82', 0),
#  (83, 'Multisynth5_Parameters_83', 0),
#  (84, 'Multisynth5_Parameters_84', 0),
#  (85, 'Multisynth5_Parameters_85', 0),
#  (86, 'Multisynth5_Parameters_86', 0),
#  (87, 'Multisynth5_Parameters_87', 0),
#  (88, 'Multisynth5_Parameters_88', 0),
#  (89, 'Multisynth5_Parameters_89', 0),
#  (90, 'Multisynth6_Parameters', 0),
#  (91, 'Multisynth7_Parameters', 0),
#  (92, 'Clock_6_and_7_Output_Divider', 0),
#  (149, 'Spread_Spectrum_Parameters_149', 0),
#  (150, 'Spread_Spectrum_Parameters_150', 0),
#  (151, 'Spread_Spectrum_Parameters_151', 0),
#  (152, 'Spread_Spectrum_Parameters_152', 0),
#  (153, 'Spread_Spectrum_Parameters_153', 0),
#  (154, 'Spread_Spectrum_Parameters_154', 0),
#  (155, 'Spread_Spectrum_Parameters_155', 0),
#  (156, 'Spread_Spectrum_Parameters_156', 0),
#  (157, 'Spread_Spectrum_Parameters_157', 0),
#  (158, 'Spread_Spectrum_Parameters_158', 0),
#  (159, 'Spread_Spectrum_Parameters_159', 0),
#  (160, 'Spread_Spectrum_Parameters_160', 0),
#  (161, 'Spread_Spectrum_Parameters_161', 0),
#  (162, 'VCXO_Parameter_162', 0),
#  (163, 'VCXO_Parameter_163', 0),
#  (164, 'VCXO_Parameter_164', 0),
#  (165, 'CLK0_Initial_Phase_Offset', 0),
#  (166, 'CLK1_Initial_Phase_Offset', 0),
#  (167, 'CLK2_Initial_Phase_Offset', 0),
#  (168, 'CLK3_Initial_Phase_Offset', 0),
#  (169, 'CLK4_Initial_Phase_Offset', 0),
#  (170, 'CLK5_Initial_Phase_Offset', 0),
#  (177, 'PLL_Reset', 0),
#  (183, 'Crystal_Internal_Load_Capacitance', 210),
#  (187, 'Fanout_Enable', 0)]

# %%
si.ready
# Out:
# True

# %%
si.status.print()
# Out:
# << Device_Status >>:  ('0x11', '0b10001')
# [ SYS_INIT ]   :  0
# [ LOL_B ]      :  0
# [ LOL_A ]      :  0
# [ LOS_CLKIN ]  :  1
# [ LOS_XTAL ]   :  0
# [ Reserved_2 ] :  0
# [ REVID ]      :  1
# 10

# %%
si.restore_clocks_freqs()

# %%
si.write_all_registers()

# %%
si.start()

# %%
si.pause()

# %%
si.resume()

# %%
si.update()

# %%
si.stop()

# %%
si.close()

# %%
si.print()
# Out:
# << Device_Status >>:  ('0x11', '0b10001')
# [ SYS_INIT ]   :  0
# [ LOL_B ]      :  0
# [ LOL_A ]      :  0
# [ LOS_CLKIN ]  :  1
# [ LOS_XTAL ]   :  0
# [ Reserved_2 ] :  0
# [ REVID ]      :  1
#
# << Interrupt_Status_Sticky >>:  ('0xf0', '0b11110000')
# [ SYS_INIT_STKY ]  :  1
# [ LOL_B_STKY ]     :  1
# [ LOL_A_STKY ]     :  1
# [ LOS_CLKIN_STKY ] :  1
# [ LOS_XTAL_STKY ]  :  0
# [ Reserved_0 ]     :  0
#
# << Interrupt_Status_Mask >>:  ('0x0', '0b0')
# [ SYS_INIT_MASK ]   :  0
# [ LOL_B_MASK ]      :  0
# [ LOL_A_MASK ]      :  0
# [ LOS__CLKIN_MASK ] :  0
# [ LOS__XTAL_MASK ]  :  0
# [ Reserved_0 ]      :  0
#
# << Output_Enable_Control >>:  ('0xff', '0b11111111')
# [ CLK7_OEB ] :  1
# [ CLK6_OEB ] :  1
# [ CLK5_OEB ] :  1
# [ CLK4_OEB ] :  1
# [ CLK3_OEB ] :  1
# [ CLK2_OEB ] :  1
# [ CLK1_OEB ] :  1
# [ CLK0_OEB ] :  1
#
# << OEB_Pin_Enable_Control_Mask >>:  ('0x0', '0b0')
# [ OEB_MASK_7 ] :  0
# [ OEB_MASK_6 ] :  0
# [ OEB_MASK_5 ] :  0
# [ OEB_MASK_4 ] :  0
# [ OEB_MASK_3 ] :  0
# [ OEB_MASK_2 ] :  0
# [ OEB_MASK_1 ] :  0
# [ OEB_MASK_0 ] :  0
#
# << PLL_Input_Source >>:  ('0x0', '0b0')
# [ CLKIN_DIV ]  :  0
# [ Reserved_4 ] :  0
# [ PLLB_SRC ]   :  0
# [ PLLA_SRC ]   :  0
# [ Reserved_0 ] :  0
#
# << CLK0_Control >>:  ('0x0', '0b0')
# [ CLK0_PDN ]  :  0
# [ MS0_INT ]   :  0
# [ MS0_SRC ]   :  0
# [ CLK0_INV ]  :  0
# [ CLK0_SRC ]  :  0
# [ CLK0_IDRV ] :  0
#
# << CLK1_Control >>:  ('0x0', '0b0')
# [ CLK1_PDN ]  :  0
# [ MS1_INT ]   :  0
# [ MS1_SRC ]   :  0
# [ CLK1_INV ]  :  0
# [ CLK1_SRC ]  :  0
# [ CLK1_IDRV ] :  0
#
# << CLK2_Control >>:  ('0x0', '0b0')
# [ CLK2_PDN ]  :  0
# [ MS2_INT ]   :  0
# [ MS2_SRC ]   :  0
# [ CLK2_INV ]  :  0
# [ CLK2_SRC ]  :  0
# [ CLK2_IDRV ] :  0
#
# << CLK3_Control >>:  ('0x0', '0b0')
# [ CLK3_PDN ]  :  0
# [ MS3_INT ]   :  0
# [ MS3_SRC ]   :  0
# [ CLK3_INV ]  :  0
# [ CLK3_SRC ]  :  0
# [ CLK3_IDRV ] :  0
#
# << CLK4_Control >>:  ('0x0', '0b0')
# [ CLK4_PDN ]  :  0
# [ MS4_INT ]   :  0
# [ MS4_SRC ]   :  0
# [ CLK4_INV ]  :  0
# [ CLK4_SRC ]  :  0
# [ CLK4_IDRV ] :  0
#
# << CLK5_Control >>:  ('0x0', '0b0')
# [ CLK5_PDN ]  :  0
# [ MS5_INT ]   :  0
# [ MS5_SRC ]   :  0
# [ CLK5_INV ]  :  0
# [ CLK5_SRC ]  :  0
# [ CLK5_IDRV ] :  0
#
# << CLK6_Control >>:  ('0x0', '0b0')
# [ CLK6_PDN ]  :  0
# [ FBA_INT ]   :  0
# [ MS6_SRC ]   :  0
# [ CLK6_INV ]  :  0
# [ CLK6_SRC ]  :  0
# [ CLK6_IDRV ] :  0
#
# << CLK7_Control >>:  ('0x0', '0b0')
# [ CLK7_PDN ]  :  0
# [ FBB_INT ]   :  0
# [ MS7_SRC ]   :  0
# [ CLK7_INV ]  :  0
# [ CLK7_SRC ]  :  0
# [ CLK7_IDRV ] :  0
#
# << CLK3_0_Disable_State >>:  ('0x0', '0b0')
# [ CLK3_DIS_STATE ] :  0
# [ CLK2_DIS_STATE ] :  0
# [ CLK1_DIS_STATE ] :  0
# [ CLK0_DIS_STATE ] :  0
#
# << CLK7_4_Disable_State >>:  ('0x0', '0b0')
# [ CLK7_DIS_STATE ] :  0
# [ CLK6_DIS_STATE ] :  0
# [ CLK5_DIS_STATE ] :  0
# [ CLK4_DIS_STATE ] :  0
#
# << Multisynth_NA_Parameters_26 >>:  ('0x0', '0b0')
# [ MSNA_P3_15_8 ] :  0
#
# << Multisynth_NA_Parameters_27 >>:  ('0x0', '0b0')
# [ MSNA_P3_7_0 ] :  0
#
# << Multisynth_NA_Parameters_28 >>:  ('0x0', '0b0')
# [ Unused ]        :  0
# [ Reserved_2 ]    :  0
# [ MSNA_P1_17_16 ] :  0
#
# << Multisynth_NA_Parameters_29 >>:  ('0x0', '0b0')
# [ MSNA_P1_15_8 ] :  0
#
# << Multisynth_NA_Parameters_30 >>:  ('0x0', '0b0')
# [ MSNA_P1_7_0 ] :  0
#
# << Multisynth_NA_Parameters_31 >>:  ('0x0', '0b0')
# [ MSNA_P3_19_16 ] :  0
# [ MSNA_P2_19_16 ] :  0
#
# << Multisynth_NA_Parameters_32 >>:  ('0x0', '0b0')
# [ MSNA_P2_15_8 ] :  0
#
# << Multisynth_NA_Parameters_33 >>:  ('0x0', '0b0')
# [ MSNA_P2_7_0 ] :  0
#
# << Multisynth_NB_Parameters_34 >>:  ('0x0', '0b0')
# [ MSNB_P3_15_8 ] :  0
#
# << Multisynth_NB_Parameters_35 >>:  ('0x0', '0b0')
# [ MSNB_P3_7_0 ] :  0
#
# << Multisynth_NB_Parameters_36 >>:  ('0x0', '0b0')
# [ Unused ]        :  0
# [ Reserved_2 ]    :  0
# [ MSNB_P1_17_16 ] :  0
#
# << Multisynth_NB_Parameters_37 >>:  ('0x0', '0b0')
# [ MSNB_P1_15_8 ] :  0
#
# << Multisynth_NB_Parameters_38 >>:  ('0x0', '0b0')
# [ MSNB_P1_7_0 ] :  0
#
# << Multisynth_NB_Parameters_39 >>:  ('0x0', '0b0')
# [ MSNB_P3_19_16 ] :  0
# [ MSNB_P2_19_16 ] :  0
#
# << Multisynth_NB_Parameters_40 >>:  ('0x0', '0b0')
# [ MSNB_P2_15_8 ] :  0
#
# << Multisynth_NB_Parameters_41 >>:  ('0x0', '0b0')
# [ MSNB_P2_7_0 ] :  0
#
# << Multisynth0_Parameters_42 >>:  ('0x0', '0b0')
# [ MS0_P3_15_8 ] :  0
#
# << Multisynth0_Parameters_43 >>:  ('0x0', '0b0')
# [ MS0_P3_7_0 ] :  0
#
# << Multisynth0_Parameters_44 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ R0_DIV ]       :  0
# [ MS0_DIVBY4 ]   :  0
# [ MS0_P1_17_16 ] :  0
#
# << Multisynth0_Parameters_45 >>:  ('0x0', '0b0')
# [ MS0_P1_15_8 ] :  0
#
# << Multisynth0_Parameters_46 >>:  ('0x0', '0b0')
# [ MS0_P1_7_0 ] :  0
#
# << Multisynth0_Parameters_47 >>:  ('0x0', '0b0')
# [ MS0_P3_19_16 ] :  0
# [ MS0_P2_19_16 ] :  0
#
# << Multisynth0_Parameters_48 >>:  ('0x0', '0b0')
# [ MS0_P2_15_8 ] :  0
#
# << Multisynth0_Parameters_49 >>:  ('0x0', '0b0')
# [ MS0_P2_7_0 ] :  0
#
# << Multisynth1_Parameters_50 >>:  ('0x0', '0b0')
# [ MS1_P3_15_8 ] :  0
#
# << Multisynth1_Parameters_51 >>:  ('0x0', '0b0')
# [ MS1_P3_7_0 ] :  0
#
# << Multisynth1_Parameters_52 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ R1_DIV ]       :  0
# [ MS1_DIVBY4 ]   :  0
# [ MS1_P1_17_16 ] :  0
#
# << Multisynth1_Parameters_53 >>:  ('0x0', '0b0')
# [ MS1_P1_15_8 ] :  0
#
# << Multisynth1_Parameters_54 >>:  ('0x0', '0b0')
# [ MS1_P1_7_0 ] :  0
#
# << Multisynth1_Parameters_55 >>:  ('0x0', '0b0')
# [ MS1_P3_19_16 ] :  0
# [ MS1_P2_19_16 ] :  0
#
# << Multisynth1_Parameters_56 >>:  ('0x0', '0b0')
# [ MS1_P2_15_8 ] :  0
#
# << Multisynth1_Parameters_57 >>:  ('0x0', '0b0')
# [ MS1_P2_7_0 ] :  0
#
# << Multisynth2_Parameters_58 >>:  ('0x0', '0b0')
# [ MS2_P3_15_8 ] :  0
#
# << Multisynth2_Parameters_59 >>:  ('0x0', '0b0')
# [ MS2_P3_7_0 ] :  0
#
# << Multisynth2_Parameters_60 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ R2_DIV ]       :  0
# [ MS2_DIVBY4 ]   :  0
# [ MS2_P1_17_16 ] :  0
#
# << Multisynth2_Parameters_61 >>:  ('0x0', '0b0')
# [ MS2_P1_15_8 ] :  0
#
# << Multisynth2_Parameters_62 >>:  ('0x0', '0b0')
# [ MS2_P1_7_0 ] :  0
#
# << Multisynth2_Parameters_63 >>:  ('0x0', '0b0')
# [ MS2_P3_19_16 ] :  0
# [ MS2_P2_19_16 ] :  0
#
# << Multisynth2_Parameters_64 >>:  ('0x0', '0b0')
# [ MS2_P2_15_8 ] :  0
#
# << Multisynth2_Parameters_65 >>:  ('0x0', '0b0')
# [ MS2_P2_7_0 ] :  0
#
# << Multisynth3_Parameters_66 >>:  ('0x0', '0b0')
# [ MS3_P3_15_8 ] :  0
#
# << Multisynth3_Parameters_67 >>:  ('0x0', '0b0')
# [ MS3_P3_7_0 ] :  0
#
# << Multisynth3_Parameters_68 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ R3_DIV ]       :  0
# [ MS3_DIVBY4 ]   :  0
# [ MS3_P1_17_16 ] :  0
#
# << Multisynth3_Parameters_69 >>:  ('0x0', '0b0')
# [ MS3_P1_15_8 ] :  0
#
# << Multisynth3_Parameters_70 >>:  ('0x0', '0b0')
# [ MS3_P1_7_0 ] :  0
#
# << Multisynth3_Parameters_71 >>:  ('0x0', '0b0')
# [ MS3_P3_19_16 ] :  0
# [ MS3_P2_19_16 ] :  0
#
# << Multisynth3_Parameters_72 >>:  ('0x0', '0b0')
# [ MS3_P2_15_8 ] :  0
#
# << Multisynth3_Parameters_73 >>:  ('0x0', '0b0')
# [ MS3_P2_7_0 ] :  0
#
# << Multisynth4_Parameters_74 >>:  ('0x0', '0b0')
# [ MS4_P3_15_8 ] :  0
#
# << Multisynth4_Parameters_75 >>:  ('0x0', '0b0')
# [ MS4_P3_7_0 ] :  0
#
# << Multisynth4_Parameters_76 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ R4_DIV ]       :  0
# [ MS4_DIVBY4 ]   :  0
# [ MS4_P1_17_16 ] :  0
#
# << Multisynth4_Parameters_77 >>:  ('0x0', '0b0')
# [ MS4_P1_15_8 ] :  0
#
# << Multisynth4_Parameters_78 >>:  ('0x0', '0b0')
# [ MS4_P1_7_0 ] :  0
#
# << Multisynth4_Parameters_79 >>:  ('0x0', '0b0')
# [ MS4_P3_19_16 ] :  0
# [ MS4_P2_19_16 ] :  0
#
# << Multisynth4_Parameters_80 >>:  ('0x0', '0b0')
# [ MS4_P2_15_8 ] :  0
#
# << Multisynth4_Parameters_81 >>:  ('0x0', '0b0')
# [ MS4_P2_7_0 ] :  0
#
# << Multisynth5_Parameters_82 >>:  ('0x0', '0b0')
# [ MS5_P3_15_8 ] :  0
#
# << Multisynth5_Parameters_83 >>:  ('0x0', '0b0')
# [ MS5_P3_7_0 ] :  0
#
# << Multisynth5_Parameters_84 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ R5_DIV ]       :  0
# [ MS5_DIVBY4 ]   :  0
# [ MS5_P1_17_16 ] :  0
#
# << Multisynth5_Parameters_85 >>:  ('0x0', '0b0')
# [ MS5_P1_15_8 ] :  0
#
# << Multisynth5_Parameters_86 >>:  ('0x0', '0b0')
# [ MS5_P1_7_0 ] :  0
#
# << Multisynth5_Parameters_87 >>:  ('0x0', '0b0')
# [ MS5_P3_19_16 ] :  0
# [ MS5_P2_19_16 ] :  0
#
# << Multisynth5_Parameters_88 >>:  ('0x0', '0b0')
# [ MS5_P2_15_8 ] :  0
#
# << Multisynth5_Parameters_89 >>:  ('0x0', '0b0')
# [ MS5_P2_7_0 ] :  0
#
# << Multisynth6_Parameters >>:  ('0x0', '0b0')
# [ MS6_P1_7_0 ] :  0
#
# << Multisynth7_Parameters >>:  ('0x0', '0b0')
# [ MS7_P1_7_0 ] :  0
#
# << Clock_6_and_7_Output_Divider >>:  ('0x0', '0b0')
# [ Reserved_7 ] :  0
# [ R7_DIV ]     :  0
# [ Reserved_3 ] :  0
# [ R6_DIV ]     :  0
#
# << Spread_Spectrum_Parameters_149 >>:  ('0x0', '0b0')
# [ SSC_EN ]       :  0
# [ SSDN_P2_14_8 ] :  0
#
# << Spread_Spectrum_Parameters_150 >>:  ('0x0', '0b0')
# [ SSDN_P2_7_0 ] :  0
#
# << Spread_Spectrum_Parameters_151 >>:  ('0x0', '0b0')
# [ SSC_MODE ]     :  0
# [ SSDN_P3_14_8 ] :  0
#
# << Spread_Spectrum_Parameters_152 >>:  ('0x0', '0b0')
# [ SSDN_P3_7_0 ] :  0
#
# << Spread_Spectrum_Parameters_153 >>:  ('0x0', '0b0')
# [ SSDN_P1_7_0 ] :  0
#
# << Spread_Spectrum_Parameters_154 >>:  ('0x0', '0b0')
# [ SSUDP_11_8 ]   :  0
# [ SSDN_P1_11_8 ] :  0
#
# << Spread_Spectrum_Parameters_155 >>:  ('0x0', '0b0')
# [ SSUDP_7_0 ] :  0
#
# << Spread_Spectrum_Parameters_156 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ SSUP_P2_14_8 ] :  0
#
# << Spread_Spectrum_Parameters_157 >>:  ('0x0', '0b0')
# [ SSUP_P2_7_0 ] :  0
#
# << Spread_Spectrum_Parameters_158 >>:  ('0x0', '0b0')
# [ Unused ]       :  0
# [ SSUP_P3_14_8 ] :  0
#
# << Spread_Spectrum_Parameters_159 >>:  ('0x0', '0b0')
# [ SSUP_P3_7_0 ] :  0
#
# << Spread_Spectrum_Parameters_160 >>:  ('0x0', '0b0')
# [ SSUP_P1_7_0 ] :  0
#
# << Spread_Spectrum_Parameters_161 >>:  ('0x0', '0b0')
# [ SS_NCLK ]      :  0
# [ SSUP_P1_11_8 ] :  0
#
# << VCXO_Parameter_162 >>:  ('0x0', '0b0')
# [ VCXO_Param_7_0 ] :  0
#
# << VCXO_Parameter_163 >>:  ('0x0', '0b0')
# [ VCXO_Param_15_8 ] :  0
#
# << VCXO_Parameter_164 >>:  ('0x0', '0b0')
# [ Reserved_6 ]       :  0
# [ VCXO_Param_21_16 ] :  0
#
# << CLK0_Initial_Phase_Offset >>:  ('0x0', '0b0')
# [ Reserved_7 ] :  0
# [ CLK0_PHOFF ] :  0
#
# << CLK1_Initial_Phase_Offset >>:  ('0x0', '0b0')
# [ Reserved_7 ] :  0
# [ CLK1_PHOFF ] :  0
#
# << CLK2_Initial_Phase_Offset >>:  ('0x0', '0b0')
# [ Reserved_7 ] :  0
# [ CLK2_PHOFF ] :  0
#
# << CLK3_Initial_Phase_Offset >>:  ('0x0', '0b0')
# [ Reserved_7 ] :  0
# [ CLK3_PHOFF ] :  0
#
# << CLK4_Initial_Phase_Offset >>:  ('0x0', '0b0')
# [ Reserved_7 ] :  0
# [ CLK4_PHOFF ] :  0
#
# << CLK5_Initial_Phase_Offset >>:  ('0x0', '0b0')
# [ Reserved_7 ] :  0
# [ CLK5_PHOFF ] :  0
#
# << PLL_Reset >>  :  ('0x0', '0b0')
# [ PLLB_RST ]   :  0
# [ Reserved_6 ] :  0
# [ PLLA_RST ]   :  0
# [ Reserved_0 ] :  0
#
# << Crystal_Internal_Load_Capacitance >>:  ('0xd2', '0b11010010')
# [ XTAL_CL ]    :  3
# [ Reserved_0 ] :  18
#
# << Fanout_Enable >>   :  ('0x0', '0b0')
# [ CLKIN_FANOUT_EN ] :  0
# [ XO_FANOUT_EN ]    :  0
# [ Reserved_5 ]      :  0
# [ MS_FANOUT_EN ]    :  0
# [ Reserved_0 ]      :  0

# %% [markdown]
# ## Spread Spectrum test

# %%
si.init()

# %%
si.spread_spectrum.enable(True, mode = 'center', ssc_amp = 0.01)

# %%
si.spread_spectrum.enable(True, mode = 'down', ssc_amp = 0.01)

# %%
si.spread_spectrum.enable(False)
